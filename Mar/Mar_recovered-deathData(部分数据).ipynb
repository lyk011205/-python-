# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time_death={}
r_d=[]
time = []
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['03-'+str(num).zfill(2)]=0
            time_death['03-'+str(num).zfill(2)]=0
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[5]!=''and row[5]!='Recovered'and row[4]!='Deaths'and row[4]!='':
                time_recovered['03-'+str(num).zfill(2)]=float(row[5])+time_recovered['03-'+str(num).zfill(2)]
                time_death['03-'+str(num).zfill(2)]=float(row[4])+time_death['03-'+str(num).zfill(2)]
times,recovered=time_recovered.keys(),time_recovered.values()
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
death=[]
for i in deaths:
    death.append(i)
recover=[]
for i in recovered:
    recover.append(i)
lens = len(time)
for i in range(lens):
    r_d.append(recover[i]-death[i])
print(r_d)
print(time)
# Out:
# [39720.0, 42517.0, 45069.0, 47917.0, 50449.0, 52406.0, 54801.0, 56892.0, 58516.0, 60142.0, 62388.0, 63604.0, 64847.0, 66805.0, 69594.0, 70962.0, 72935.0, 74580.0, 75095.0, 76104.0, 78703.0]
# ['03-01', '03-02', '03-03', '03-04', '03-05', '03-06', '03-07', '03-08', '03-09', '03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', '03-18', '03-19', '03-20', '03-21']

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered - Death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered - death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,r_d,s=100)

# %%
new={}
for key in time_recovered.keys():
    if key!='03-01':
        new[key]=time_recovered[key]-time_recovered['03-'+str(int(key[3:5])-1).zfill(2)]-time_death[key]+time_death['03-'+str(int(key[3:5])-1).zfill(2)]
print(new)
time1=new.keys()
value1=new.values()
plt.figure(dpi=800)
plt.title('new recovered-death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of  recovered-death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,value1,s=100)
plt.show()
# Out:
# {'03-02': 2797.0, '03-03': 2552.0, '03-04': 2848.0, '03-05': 2532.0, '03-06': 1957.0, '03-07': 2395.0, '03-08': 2091.0, '03-09': 1624.0, '03-10': 1626.0, '03-11': 2246.0, '03-12': 1216.0, '03-13': 1243.0, '03-14': 1958.0, '03-15': 2789.0, '03-16': 1368.0, '03-17': 1973.0, '03-18': 1645.0, '03-19': 515.0, '03-20': 1009.0, '03-21': 2599.0}

# %%
fig = plt.figure(dpi=128,figsize=(10,6))
plt.title('cumulative Recovered - Death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time,r_d,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
value2=[]
for i in value1:
    value2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered - death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time2,value2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, r_d, label='Recovered - Death')
plt.title('cumulative Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered - death',fontsize = 16)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, value2, label='Recovered - Death')
plt.title('new Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of Recovered - Death',fontsize = 24)
plt.show()
