# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_confirmed={}
time = []
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_confirmed['03-'+str(num).zfill(2)]=0
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[3]!=''and row[3]!='Confirmed':
                time_confirmed['03-'+str(num).zfill(2)]=float(row[3])+time_confirmed['03-'+str(num).zfill(2)]
print(time_confirmed)
times,confirmed=time_confirmed.keys(),time_confirmed.values()
for i in times:
    time.append(i)
# Out:
# {'03-01': 88371.0, '03-02': 90309.0, '03-03': 92844.0, '03-04': 95124.0, '03-05': 97886.0, '03-06': 101800.0, '03-07': 105836.0, '03-08': 109835.0, '03-09': 113582.0, '03-10': 118582.0, '03-11': 125865.0, '03-12': 128343.0, '03-13': 145193.0, '03-14': 156099.0, '03-15': 167447.0, '03-16': 181546.0, '03-17': 197168.0, '03-18': 214915.0, '03-19': 242713.0, '03-20': 272167.0, '03-21': 304549.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,confirmed,s=100)
plt.show()

# %%
new_time_confirmed={}
for key in time_confirmed.keys():
    if key!='03-01':
        new_time_confirmed[key]=time_confirmed[key]-time_confirmed['03-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_confirmed)
time1=new_time_confirmed.keys()
confirmed1=new_time_confirmed.values()
plt.figure(dpi=800)
plt.title('new confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,confirmed1,s=100)
plt.show()
# Out:
# {'03-02': 1938.0, '03-03': 2535.0, '03-04': 2280.0, '03-05': 2762.0, '03-06': 3914.0, '03-07': 4036.0, '03-08': 3999.0, '03-09': 3747.0, '03-10': 5000.0, '03-11': 7283.0, '03-12': 2478.0, '03-13': 16850.0, '03-14': 10906.0, '03-15': 11348.0, '03-16': 14099.0, '03-17': 15622.0, '03-18': 17747.0, '03-19': 27798.0, '03-20': 29454.0, '03-21': 32382.0}

# %%
confirm=[]
for i in confirmed:
    confirm.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time,confirm,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
confirmed2=[]
for i in confirmed1:
    confirmed2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time2,confirmed2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, confirm, label='confirmed')
plt.title('cumulative confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, confirmed2, label='confirmed')
plt.title('new confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of confirmed',fontsize = 24)
plt.show()
