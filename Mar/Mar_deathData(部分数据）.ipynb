# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_death={}
time = []
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_death['03-'+str(num).zfill(2)]=0
for num in range(1,22):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\03-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[4]!=''and row[4]!='Deaths':
                time_death['03-'+str(num).zfill(2)]=float(row[4])+time_death['03-'+str(num).zfill(2)]
print(time_death)
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
# Out:
# {'03-01': 2996.0, '03-02': 3085.0, '03-03': 3160.0, '03-04': 3254.0, '03-05': 3348.0, '03-06': 3460.0, '03-07': 3558.0, '03-08': 3803.0, '03-09': 3996.0, '03-10': 4262.0, '03-11': 4615.0, '03-12': 4720.0, '03-13': 5404.0, '03-14': 5819.0, '03-15': 6440.0, '03-16': 7126.0, '03-17': 7905.0, '03-18': 8733.0, '03-19': 9867.0, '03-20': 11299.0, '03-21': 12973.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,deaths,s=100)
plt.show()

# %%
new_time_death={}
for key in time_death.keys():
    if key!='03-01':
        new_time_death[key]=time_death[key]-time_death['03-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_death)
time1=new_time_death.keys()
death1=new_time_death.values()
plt.figure(dpi=800)
plt.title('new death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,death1,s=100)
plt.show()
# Out:
# {'03-02': 89.0, '03-03': 75.0, '03-04': 94.0, '03-05': 94.0, '03-06': 112.0, '03-07': 98.0, '03-08': 245.0, '03-09': 193.0, '03-10': 266.0, '03-11': 353.0, '03-12': 105.0, '03-13': 684.0, '03-14': 415.0, '03-15': 621.0, '03-16': 686.0, '03-17': 779.0, '03-18': 828.0, '03-19': 1134.0, '03-20': 1432.0, '03-21': 1674.0}

# %%
death=[]
for i in deaths:
    death.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time,death,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
death2=[]
for i in death1:
    death2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time2,death2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, death, label='death')
plt.title('cumulative death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, death1, label='death')
plt.title('new death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()
