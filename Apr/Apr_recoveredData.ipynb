# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time = []
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['04-'+str(num).zfill(2)]=0
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[9]!=''and row[9]!='Recovered':
                time_recovered['04-'+str(num).zfill(2)]=float(row[9])+time_recovered['04-'+str(num).zfill(2)]
print(time_recovered)
times,recovered=time_recovered.keys(),time_recovered.values()
for i in times:
    time.append(i)
# Out:
# {'04-01': 193171.0, '04-02': 210263.0, '04-03': 225796.0, '04-04': 246152.0, '04-05': 260012.0, '04-06': 276515.0, '04-07': 300054.0, '04-08': 328661.0, '04-09': 353975.0, '04-10': 376096.0, '04-11': 402110.0, '04-12': 421722.0, '04-13': 448655.0, '04-14': 474261.0, '04-15': 511019.0, '04-16': 542107.0, '04-17': 568343.0, '04-18': 592319.0, '04-19': 623903.0, '04-20': 645738.0, '04-21': 679819.0, '04-22': 709694.0, '04-23': 738486.0, '04-24': 793420.0, '04-25': 816685.0, '04-26': 865733.0, '04-27': 893967.0, '04-28': 928658.0, '04-29': 972719.0, '04-30': 1014753.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,recovered,s=100)
plt.show()

# %%
new_time_recovered={}
for key in time_recovered.keys():
    if key!='04-01':
        new_time_recovered[key]=time_recovered[key]-time_recovered['04-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_recovered)
time1=new_time_recovered.keys()
recover1=new_time_recovered.values()
plt.figure(dpi=800)
plt.title('new recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,recover1,s=100)
plt.show()
# Out:
# {'04-02': 17092.0, '04-03': 15533.0, '04-04': 20356.0, '04-05': 13860.0, '04-06': 16503.0, '04-07': 23539.0, '04-08': 28607.0, '04-09': 25314.0, '04-10': 22121.0, '04-11': 26014.0, '04-12': 19612.0, '04-13': 26933.0, '04-14': 25606.0, '04-15': 36758.0, '04-16': 31088.0, '04-17': 26236.0, '04-18': 23976.0, '04-19': 31584.0, '04-20': 21835.0, '04-21': 34081.0, '04-22': 29875.0, '04-23': 28792.0, '04-24': 54934.0, '04-25': 23265.0, '04-26': 49048.0, '04-27': 28234.0, '04-28': 34691.0, '04-29': 44061.0, '04-30': 42034.0}

# %%
recover=[]
for i in recovered:
    recover.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time,recover,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
recover2=[]
for i in recover1:
    recover2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time2,recover2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, recover, label='recovered')
plt.title('cumulative recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, recover2, label='recovered')
plt.title('new recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()
