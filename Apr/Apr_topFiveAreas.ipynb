# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
area_death={}
areas_death={}
area_comfirmed={}
areas_comfirmed={}
area_recovered={}
areas_recovered={}
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            area_death[row[3]]=0
            area_comfirmed[row[3]]=0
            area_recovered[row[3]]=0
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[7]!=''and row[8]!='Deaths' and row[3]!=''and row[8]!='':
                area_death[row[3]]=area_death[row[3]]+int(row[8])
                area_comfirmed[row[3]]=area_comfirmed[row[3]]+int(row[7])
                area_recovered[row[3]]=area_recovered[row[3]]+int(row[9])
print(area_death)
#print( sorted(area_death.items(), key=lambda x: x[1], reverse=True)[0][0])
for i in range(0,5):
    areas_death[sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_comfirmed[sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_recovered[sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][1])
print(areas_death)
print(areas_comfirmed)
print(areas_recovered)
areas1=areas_death.keys()
death=areas_death.values()
areas2=areas_comfirmed.keys()
comfirmed = areas_comfirmed.values()
areas3=areas_recovered.keys()
recovered = areas_recovered.values()
# Out:
# {'US': 960515, 'Canada': 40556, 'United Kingdom': 398163, 'China': 118290, 'Netherlands': 94860, 'Australia': 1817, 'Denmark': 9093, 'France': 486897, 'Afghanistan': 860, 'Albania': 728, 'Algeria': 9197, 'Andorra': 917, 'Angola': 60, 'Antigua and Barbuda': 62, 'Argentina': 3482, 'Armenia': 527, 'Austria': 11663, 'Azerbaijan': 429, 'Bahamas': 235, 'Bahrain': 190, 'Bangladesh': 2153, 'Barbados': 122, 'Belarus': 1171, 'Belgium': 132664, 'Belize': 46, 'Benin': 25, 'Bhutan': 0, 'Bolivia': 882, 'Bosnia and Herzegovina': 1272, 'Botswana': 30, 'Brazil': 66571, 'Brunei': 30, 'Bulgaria': 1111, 'Burkina Faso': 921, 'Burma': 110, 'Burundi': 18, 'Cabo Verde': 30, 'Cambodia': 0, 'Cameroon': 825, 'Central African Republic': 0, 'Chad': 9, 'Chile': 3274, 'Colombia': 4236, 'Congo (Brazzaville)': 157, 'Congo (Kinshasa)': 659, 'Costa Rica': 122, "Cote d'Ivoire": 226, 'Croatia': 1043, 'Cuba': 862, 'Cyprus': 354, 'Czechia': 4582, 'Diamond Princess': 361, 'Djibouti': 41, 'Dominica': 0, 'Dominican Republic': 5552, 'Ecuador': 12586, 'Egypt': 6017, 'El Salvador': 181, 'Equatorial Guinea': 9, 'Eritrea': 0, 'Estonia': 978, 'Eswatini': 15, 'Ethiopia': 73, 'Fiji': 0, 'Finland': 2863, 'Gabon': 45, 'Gambia': 30, 'Georgia': 104, 'Germany': 115270, 'Ghana': 254, 'Greece': 3088, 'Grenada': 0, 'Guatemala': 205, 'Guinea': 84, 'Guinea-Bissau': 5, 'Guyana': 183, 'Haiti': 93, 'Holy See': 0, 'Honduras': 1107, 'Hungary': 4482, 'Iceland': 234, 'India': 14417, 'Indonesia': 14067, 'Iran': 141323, 'Iraq': 2275, 'Ireland': 16660, 'Israel': 3960, 'Italy': 644171, 'Jamaica': 147, 'Japan': 6051, 'Jordan': 200, 'Kazakhstan': 442, 'Kenya': 297, 'Korea, South': 6533, 'Kosovo': 253, 'Kuwait': 234, 'Kyrgyzstan': 154, 'Laos': 0, 'Latvia': 185, 'Lebanon': 616, 'Liberia': 202, 'Libya': 38, 'Liechtenstein': 27, 'Lithuania': 845, 'Luxembourg': 1943, 'MS Zaandam': 60, 'Madagascar': 0, 'Malaysia': 2393, 'Maldives': 2, 'Mali': 382, 'Malta': 71, 'Mauritania': 30, 'Mauritius': 255, 'Mexico': 18449, 'Moldova': 1591, 'Monaco': 70, 'Mongolia': 0, 'Montenegro': 122, 'Morocco': 3613, 'Mozambique': 0, 'Namibia': 0, 'Nepal': 0, 'New Zealand': 272, 'Nicaragua': 51, 'Niger': 511, 'Nigeria': 574, 'North Macedonia': 1283, 'Norway': 4258, 'Oman': 164, 'Pakistan': 4503, 'Panama': 3087, 'Papua New Guinea': 0, 'Paraguay': 204, 'Peru': 11056, 'Philippines': 10091, 'Poland': 9321, 'Portugal': 18022, 'Qatar': 215, 'Romania': 11630, 'Russia': 10123, 'Rwanda': 0, 'Saint Kitts and Nevis': 0, 'Saint Lucia': 0, 'Saint Vincent and the Grenadines': 0, 'San Marino': 1094, 'Saudi Arabia': 2487, 'Senegal': 118, 'Serbia': 2827, 'Seychelles': 0, 'Sierra Leone': 28, 'Singapore': 282, 'Slovakia': 260, 'Slovenia': 1746, 'Somalia': 246, 'South Africa': 1363, 'Spain': 548160, 'Sri Lanka': 193, 'Sudan': 282, 'Suriname': 28, 'Sweden': 39340, 'Switzerland': 36069, 'Syria': 72, 'Taiwan*': 171, 'Tanzania': 171, 'Thailand': 1182, 'Timor-Leste': 0, 'Togo': 133, 'Trinidad and Tobago': 229, 'Tunisia': 940, 'Turkey': 49592, 'Uganda': 0, 'Ukraine': 3615, 'United Arab Emirates': 1170, 'Uruguay': 277, 'Uzbekistan': 144, 'Venezuela': 266, 'Vietnam': 0, 'West Bank and Gaza': 61, 'Zambia': 62, 'Zimbabwe': 86, 'Malawi': 53, 'South Sudan': 0, 'Western Sahara': 0, 'Sao Tome and Principe': 0, 'Yemen': 2, 'Comoros': 0, 'Tajikistan': 0}
# {'US': 960515, 'Italy': 644171, 'Spain': 548160, 'France': 486897, 'United Kingdom': 398163}
# {'US': 19518497, 'Spain': 5355694, 'Italy': 4928524, 'France': 3987918, 'Germany': 3942925}
# {'China': 2333016, 'Germany': 2191330, 'Spain': 2151803, 'US': 1747977, 'Iran': 1432550}

# %% [markdown]
# 列举四月前五的death地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas1, death, label='death')
plt.title('death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of death',fontsize = 24)
plt.show()

# %% [markdown]
# 列举四月前五的comfirmed地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas2, comfirmed, label='comfirmed')
plt.title('comfirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of comfirmed',fontsize = 24)
plt.show()

# %% [markdown]
# 列举四月前五的rrecovered地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas3, recovered, label='recovered')
plt.title('recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of recovered',fontsize = 24)
plt.show()
