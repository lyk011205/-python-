# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time_death={}
r_d=[]
time = []
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['04-'+str(num).zfill(2)]=0
            time_death['04-'+str(num).zfill(2)]=0
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[9]!=''and row[9]!='Recovered'and row[8]!='Deaths'and row[8]!='':
                time_recovered['04-'+str(num).zfill(2)]=float(row[9])+time_recovered['04-'+str(num).zfill(2)]
                time_death['04-'+str(num).zfill(2)]=float(row[8])+time_death['04-'+str(num).zfill(2)]
times,recovered=time_recovered.keys(),time_recovered.values()
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
death=[]
for i in deaths:
    death.append(i)
recover=[]
for i in recovered:
    recover.append(i)
lens = len(time)
for i in range(lens):
    r_d.append(recover[i]-death[i])
print(r_d)
print(time)
# Out:
# [146362.0, 157280.0, 167009.0, 181546.0, 190638.0, 201950.0, 218189.0, 240323.0, 258520.0, 273571.0, 293608.0, 307633.0, 329173.0, 348277.0, 376842.0, 398306.0, 414521.0, 432809.0, 458859.0, 475752.0, 503236.0, 526628.0, 547628.0, 596269.0, 613839.0, 659189.0, 682800.0, 711505.0, 745081.0, 781365.0]
# ['04-01', '04-02', '04-03', '04-04', '04-05', '04-06', '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13', '04-14', '04-15', '04-16', '04-17', '04-18', '04-19', '04-20', '04-21', '04-22', '04-23', '04-24', '04-25', '04-26', '04-27', '04-28', '04-29', '04-30']

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered - Death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered - death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,r_d,s=100)

# %%
new={}
for key in time_recovered.keys():
    if key!='04-01':
        new[key]=time_recovered[key]-time_recovered['04-'+str(int(key[3:5])-1).zfill(2)]-time_death[key]+time_death['04-'+str(int(key[3:5])-1).zfill(2)]
print(new)
time1=new.keys()
value1=new.values()
plt.figure(dpi=800)
plt.title('new recovered-death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of  recovered-death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,value1,s=100)
plt.show()
# Out:
# {'04-02': 10918.0, '04-03': 9729.0, '04-04': 14537.0, '04-05': 9092.0, '04-06': 11312.0, '04-07': 16239.0, '04-08': 22134.0, '04-09': 18197.0, '04-10': 15051.0, '04-11': 20037.0, '04-12': 14025.0, '04-13': 21540.0, '04-14': 19104.0, '04-15': 28565.0, '04-16': 21464.0, '04-17': 16215.0, '04-18': 18288.0, '04-19': 26050.0, '04-20': 16893.0, '04-21': 27484.0, '04-22': 23392.0, '04-23': 21000.0, '04-24': 48641.0, '04-25': 17570.0, '04-26': 45350.0, '04-27': 23611.0, '04-28': 28705.0, '04-29': 33576.0, '04-30': 36284.0}

# %%
fig = plt.figure(dpi=128,figsize=(10,6))
plt.title('cumulative Recovered - Death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time,r_d,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
value2=[]
for i in value1:
    value2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered - death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time2,value2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, r_d, label='Recovered - Death')
plt.title('cumulative Recovered - Death',fontsize=24)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered - death',fontsize = 16)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, value2, label='Recovered - Death')
plt.title('new Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of Recovered - Death',fontsize = 24)
plt.show()
