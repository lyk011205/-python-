# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_confirmed={}
time = []
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_confirmed['04-'+str(num).zfill(2)]=0
for num in range(1,31):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\04-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[7]!=''and row[7]!='Confirmed':
                time_confirmed['04-'+str(num).zfill(2)]=float(row[7])+time_confirmed['04-'+str(num).zfill(2)]
print(time_confirmed)
times,confirmed=time_confirmed.keys(),time_confirmed.values()
for i in times:
    time.append(i)
# Out:
# {'04-01': 932605.0, '04-02': 1013303.0, '04-03': 1095917.0, '04-04': 1197408.0, '04-05': 1272115.0, '04-06': 1345101.0, '04-07': 1426096.0, '04-08': 1511104.0, '04-09': 1595350.0, '04-10': 1691719.0, '04-11': 1771514.0, '04-12': 1846680.0, '04-13': 1917320.0, '04-14': 1976192.0, '04-15': 2056055.0, '04-16': 2152647.0, '04-17': 2240191.0, '04-18': 2317759.0, '04-19': 2401379.0, '04-20': 2472259.0, '04-21': 2549123.0, '04-22': 2623960.0, '04-23': 2708885.0, '04-24': 2810715.0, '04-25': 2896746.0, '04-26': 2971475.0, '04-27': 3041764.0, '04-28': 3116398.0, '04-29': 3193886.0, '04-30': 3256846.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,confirmed,s=100)
plt.show()

# %%
new_time_confirmed={}
for key in time_confirmed.keys():
    if key!='04-01':
        new_time_confirmed[key]=time_confirmed[key]-time_confirmed['04-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_confirmed)
time1=new_time_confirmed.keys()
confirmed1=new_time_confirmed.values()
plt.figure(dpi=800)
plt.title('new confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,confirmed1,s=100)
plt.show()
# Out:
# {'04-02': 80698.0, '04-03': 82614.0, '04-04': 101491.0, '04-05': 74707.0, '04-06': 72986.0, '04-07': 80995.0, '04-08': 85008.0, '04-09': 84246.0, '04-10': 96369.0, '04-11': 79795.0, '04-12': 75166.0, '04-13': 70640.0, '04-14': 58872.0, '04-15': 79863.0, '04-16': 96592.0, '04-17': 87544.0, '04-18': 77568.0, '04-19': 83620.0, '04-20': 70880.0, '04-21': 76864.0, '04-22': 74837.0, '04-23': 84925.0, '04-24': 101830.0, '04-25': 86031.0, '04-26': 74729.0, '04-27': 70289.0, '04-28': 74634.0, '04-29': 77488.0, '04-30': 62960.0}

# %%
confirm=[]
for i in confirmed:
    confirm.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time,confirm,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
confirmed2=[]
for i in confirmed1:
    confirmed2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time2,confirmed2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, confirm, label='confirmed')
plt.title('cumulative confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, confirmed2, label='confirmed')
plt.title('new confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of confirmed',fontsize = 24)
plt.show()
