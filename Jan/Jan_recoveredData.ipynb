# %%
import csv

# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time = []
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['01-'+str(num).zfill(2)]=0
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[5]!=''and row[5]!='Recovered':
                time_recovered['01-'+str(num).zfill(2)]=float(row[5])+time_recovered['01-'+str(num).zfill(2)]
print(time_recovered)
times,recovered=time_recovered.keys(),time_recovered.values()
for i in times:
    time.append(i)
# Out:
# {'01-22': 28.0, '01-23': 30.0, '01-24': 36.0, '01-25': 39.0, '01-26': 52.0, '01-27': 61.0, '01-28': 107.0, '01-29': 126.0, '01-30': 143.0, '01-31': 222.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,recovered,s=100)
plt.show()

# %%
new_time_recovered={}
for key in time_recovered.keys():
    if key!='01-22':
        new_time_recovered[key]=time_recovered[key]-time_recovered['01-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_recovered)
time1=new_time_recovered.keys()
recover1=new_time_recovered.values()
plt.figure(dpi=800)
plt.title('new recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,recover1,s=100)
plt.show()
# Out:
# {'01-23': 2.0, '01-24': 6.0, '01-25': 3.0, '01-26': 13.0, '01-27': 9.0, '01-28': 46.0, '01-29': 19.0, '01-30': 17.0, '01-31': 79.0}

# %%
recover=[]
for i in recovered:
    recover.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time,recover,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
recover2=[]
for i in recover1:
    recover2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time2,recover2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, recover, label='recovered')
plt.title('cumulative recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, recover2, label='recovered')
plt.title('new recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()
