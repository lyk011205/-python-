# %%
import csv

# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_death={}
time = []
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_death['01-'+str(num).zfill(2)]=0
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[4]!=''and row[4]!='Deaths':
                time_death['01-'+str(num).zfill(2)]=float(row[4])+time_death['01-'+str(num).zfill(2)]
print(time_death)
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
# Out:
# {'01-22': 17.0, '01-23': 18.0, '01-24': 26.0, '01-25': 42.0, '01-26': 56.0, '01-27': 82.0, '01-28': 131.0, '01-29': 133.0, '01-30': 171.0, '01-31': 213.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,deaths,s=100)
plt.show()

# %%
new_time_death={}
for key in time_death.keys():
    if key!='01-22':
        new_time_death[key]=time_death[key]-time_death['01-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_death)
time1=new_time_death.keys()
death1=new_time_death.values()
plt.figure(dpi=800)
plt.title('new death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,death1,s=100)
plt.show()
# Out:
# {'01-23': 1.0, '01-24': 8.0, '01-25': 16.0, '01-26': 14.0, '01-27': 26.0, '01-28': 49.0, '01-29': 2.0, '01-30': 38.0, '01-31': 42.0}

# %%
death=[]
for i in deaths:
    death.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time,death,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
death2=[]
for i in death1:
    death2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time2,death2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, death, label='death')
plt.title('cumulative death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, death1, label='death')
plt.title('new death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()
