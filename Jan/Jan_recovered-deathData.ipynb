# %%
import csv

# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time_death={}
r_d=[]
time = []
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['01-'+str(num).zfill(2)]=0
            time_death['01-'+str(num).zfill(2)]=0
for num in range(22,32):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\01-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[5]!=''and row[5]!='Recovered'and row[4]!='Deaths'and row[4]!='':
                time_recovered['01-'+str(num).zfill(2)]=float(row[5])+time_recovered['01-'+str(num).zfill(2)]
                time_death['01-'+str(num).zfill(2)]=float(row[4])+time_death['01-'+str(num).zfill(2)]
times,recovered=time_recovered.keys(),time_recovered.values()
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
death=[]
for i in deaths:
    death.append(i)
recover=[]
for i in recovered:
    recover.append(i)
lens = len(time)
for i in range(lens):
    r_d.append(recover[i]-death[i])
print(r_d)
print(time)
# Out:
# [11.0, 11.0, 7.0, -8.0, -10.0, -28.0, -39.0, -31.0, -65.0, -50.0]
# ['01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28', '01-29', '01-30', '01-31']

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered - Death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered - death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,r_d,s=100)

# %%
new={}
for key in time_recovered.keys():
    if key!='01-22':
        new[key]=time_recovered[key]-time_recovered['01-'+str(int(key[3:5])-1).zfill(2)]-time_death[key]+time_death['01-'+str(int(key[3:5])-1).zfill(2)]
print(new)
time1=new.keys()
value1=new.values()
plt.figure(dpi=800)
plt.title('new recovered-death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of  recovered-death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,value1,s=100)
plt.show()
# Out:
# {'01-23': 0.0, '01-24': -4.0, '01-25': -15.0, '01-26': -2.0, '01-27': -18.0, '01-28': -11.0, '01-29': 8.0, '01-30': -34.0, '01-31': 15.0}

# %%
fig = plt.figure(dpi=128,figsize=(10,6))
plt.title('cumulative Recovered - Death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time,r_d,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
value2=[]
for i in value1:
    value2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered - death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time2,value2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, r_d, label='Recovered - Death')
plt.title('cumulative Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered - death',fontsize = 16)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, value2, label='Recovered - Death')
plt.title('new Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of Recovered - Death',fontsize = 24)
plt.show()
