# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
area_death={}
areas_death={}
area_comfirmed={}
areas_comfirmed={}
area_recovered={}
areas_recovered={}
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            area_death[row[0]]=0
            area_comfirmed[row[0]]=0
            area_recovered[row[0]]=0
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[4]!=''and row[4]!='Deaths' and row[0]!=''and row[5]!='':
                area_death[row[0]]=area_death[row[0]]+int(row[4])
                area_comfirmed[row[0]]=area_comfirmed[row[0]]+int(row[3])
                area_recovered[row[0]]=area_recovered[row[0]]+int(row[5])
print(area_death)
#print( sorted(area_death.items(), key=lambda x: x[1], reverse=True)[0][0])
for i in range(0,5):
    areas_death[sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_comfirmed[sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_recovered[sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][1])
print(areas_death)
print(areas_comfirmed)
print(areas_recovered)
areas1=areas_death.keys()
death=areas_death.values()
areas2=areas_comfirmed.keys()
comfirmed = areas_comfirmed.values()
areas3=areas_recovered.keys()
recovered = areas_recovered.values()
# Out:
# {'Hubei': 44620, 'Zhejiang': 10, 'Guangdong': 89, 'Henan': 341, 'Hunan': 66, 'Anhui': 113, 'Jiangxi': 20, 'Chongqing': 119, 'Sichuan': 57, 'Shandong': 72, 'Jiangsu': 0, 'Shanghai': 48, 'Beijing': 93, 'Fujian': 10, 'Shaanxi': 10, 'Guangxi': 38, 'Hebei': 97, 'Yunnan': 21, 'Heilongjiang': 249, 'Liaoning': 18, 'Hainan': 98, 'Shanxi': 0, 'Tianjin': 61, 'Gansu': 43, 'Guizhou': 37, 'Ningxia': 0, 'Inner Mongolia': 0, '': 0, 'Xinjiang': 27, 'Jilin': 23, 'Hong Kong': 37, 'Taiwan': 14, 'Qinghai': 0, 'Macau': 0, 'New South Wales': 0, 'Victoria': 0, 'Queensland': 0, 'Ontario': 0, 'Chicago, IL': 0, 'South Australia': 0, 'British Columbia': 0, 'Tibet': 0, 'Boston, MA': 0, 'Los Angeles, CA': 0, 'Orange, CA': 0, 'Santa Clara, CA': 0, 'Seattle, WA': 1, 'Tempe, AZ': 0, 'San Benito, CA': 0, 'Toronto, ON': 0, 'London, ON': 0, 'Madison, WI': 0, 'Cruise Ship': 0, 'Diamond Princess cruise ship': 35, 'San Diego County, CA': 0, 'San Antonio, TX': 0, 'Ashland, NE': 0, 'Travis, CA': 0, 'From Diamond Princess': 0, 'Lackland, TX': 0, 'None': 0, 'Humboldt County, CA': 0, 'Sacramento County, CA': 0, 'Omaha, NE (From Diamond Princess)': 0, 'Travis, CA (From Diamond Princess)': 0, 'Lackland, TX (From Diamond Princess)': 0, 'Unassigned Location (From Diamond Princess)': 0, ' Montreal, QC': 0, 'Western Australia': 0, 'Portland, OR': 0, 'Snohomish County, WA': 0}
# {'Hubei': 44620, 'Henan': 341, 'Heilongjiang': 249, 'Chongqing': 119, 'Anhui': 113}
# {'Hubei': 1316575, 'Guangdong': 33907, 'Zhejiang': 31295, 'Henan': 31275, 'Hunan': 25620}
# {'Hubei': 252317, 'Henan': 13656, 'Zhejiang': 13126, 'Guangdong': 12521, 'Hunan': 12066}

# %% [markdown]
# 列举二月前五的death地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas1, death, label='death')
plt.title('death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of death',fontsize = 24)
plt.show()

# %% [markdown]
# 列举二月前五的comfirmed地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas2, comfirmed, label='comfirmed')
plt.title('comfirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of comfirmed',fontsize = 24)
plt.show()

# %% [markdown]
# 列举二月前五的recovered地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas3, recovered, label='recovered')
plt.title('recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of recovered',fontsize = 24)
plt.show()
