# %%
import csv

# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
area_death={}
time_death={}
time = []
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_death['02-'+str(num).zfill(2)]=0
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[4]!=''and row[4]!='Deaths'and row[0]!='':
                time_death['02-'+str(num).zfill(2)]=float(row[4])+time_death['02-'+str(num).zfill(2)]
print(time_death)
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
# Out:
# {'02-01': 259.0, '02-02': 361.0, '02-03': 425.0, '02-04': 491.0, '02-05': 563.0, '02-06': 633.0, '02-07': 718.0, '02-08': 805.0, '02-09': 905.0, '02-10': 1012.0, '02-11': 1112.0, '02-12': 1117.0, '02-13': 1369.0, '02-14': 1521.0, '02-15': 1663.0, '02-16': 1767.0, '02-17': 1865.0, '02-18': 2004.0, '02-19': 2117.0, '02-20': 2241.0, '02-21': 2241.0, '02-22': 2446.0, '02-23': 2449.0, '02-24': 2599.0, '02-25': 2669.0, '02-26': 2722.0, '02-27': 2751.0, '02-28': 2797.0, '02-29': 2845.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,deaths,s=100)
plt.show()

# %%
new_time_death={}
for key in time_death.keys():
    if key!='02-01':
        new_time_death[key]=time_death[key]-time_death['02-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_death)
time1=new_time_death.keys()
death1=new_time_death.values()
plt.figure(dpi=800)
plt.title('new death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,death1,s=100)
plt.show()
# Out:
# {'02-02': 103.0, '02-03': 64.0, '02-04': 66.0, '02-05': 72.0, '02-06': 70.0, '02-07': 85.0, '02-08': 87.0, '02-09': 100.0, '02-10': 107.0, '02-11': 100.0, '02-12': 5.0, '02-13': 253.0, '02-14': 152.0, '02-15': 143.0, '02-16': 104.0, '02-17': 98.0, '02-18': 139.0, '02-19': 115.0, '02-20': 125.0, '02-21': 4.0, '02-22': 207.0, '02-23': 11.0, '02-24': 160.0, '02-25': 79.0, '02-26': 62.0, '02-27': 44.0, '02-28': 58.0, '02-29': 69.0}

# %%
death=[]
for i in deaths:
    death.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time,death,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
death2=[]
for i in death1:
    death2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time2,death2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, death, label='death')
plt.title('cumulative death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, death1, label='death')
plt.title('new death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()
