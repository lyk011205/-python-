# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_confirmed={}
time = []
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_confirmed['02-'+str(num).zfill(2)]=0
for num in range(1,30):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\02-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[3]!=''and row[3]!='Confirmed':
                time_confirmed['02-'+str(num).zfill(2)]=float(row[3])+time_confirmed['02-'+str(num).zfill(2)]
print(time_confirmed)
times,confirmed=time_confirmed.keys(),time_confirmed.values()
for i in times:
    time.append(i)
# Out:
# {'02-01': 12038.0, '02-02': 16787.0, '02-03': 19881.0, '02-04': 23892.0, '02-05': 27636.0, '02-06': 30818.0, '02-07': 34392.0, '02-08': 37121.0, '02-09': 40151.0, '02-10': 42763.0, '02-11': 44803.0, '02-12': 45222.0, '02-13': 60370.0, '02-14': 66887.0, '02-15': 69032.0, '02-16': 71226.0, '02-17': 73260.0, '02-18': 75138.0, '02-19': 75641.0, '02-20': 76199.0, '02-21': 76843.0, '02-22': 78599.0, '02-23': 78985.0, '02-24': 79570.0, '02-25': 80415.0, '02-26': 81397.0, '02-27': 82756.0, '02-28': 84124.0, '02-29': 86013.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,confirmed,s=100)
plt.show()

# %%
new_time_confirmed={}
for key in time_confirmed.keys():
    if key!='02-01':
        new_time_confirmed[key]=time_confirmed[key]-time_confirmed['02-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_confirmed)
time1=new_time_confirmed.keys()
confirmed1=new_time_confirmed.values()
plt.figure(dpi=800)
plt.title('new confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,confirmed1,s=100)
plt.show()
# Out:
# {'02-02': 4749.0, '02-03': 3094.0, '02-04': 4011.0, '02-05': 3744.0, '02-06': 3182.0, '02-07': 3574.0, '02-08': 2729.0, '02-09': 3030.0, '02-10': 2612.0, '02-11': 2040.0, '02-12': 419.0, '02-13': 15148.0, '02-14': 6517.0, '02-15': 2145.0, '02-16': 2194.0, '02-17': 2034.0, '02-18': 1878.0, '02-19': 503.0, '02-20': 558.0, '02-21': 644.0, '02-22': 1756.0, '02-23': 386.0, '02-24': 585.0, '02-25': 845.0, '02-26': 982.0, '02-27': 1359.0, '02-28': 1368.0, '02-29': 1889.0}

# %%
confirm=[]
for i in confirmed:
    confirm.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time,confirm,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
confirmed2=[]
for i in confirmed1:
    confirmed2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time2,confirmed2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, confirm, label='confirmed')
plt.title('cumulative confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, confirmed2, label='confirmed')
plt.title('new confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of confirmed',fontsize = 24)
plt.show()
