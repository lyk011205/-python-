# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_confirmed={}
time = []
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_confirmed['05-'+str(num).zfill(2)]=0
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[7]!=''and row[7]!='Confirmed':
                time_confirmed['05-'+str(num).zfill(2)]=float(row[7])+time_confirmed['05-'+str(num).zfill(2)]
print(time_confirmed)
times,confirmed=time_confirmed.keys(),time_confirmed.values()
for i in times:
    time.append(i)
# Out:
# {'05-01': 3343777.0, '05-02': 3427343.0, '05-03': 3506729.0, '05-04': 3583055.0, '05-05': 3662691.0, '05-06': 3755341.0, '05-07': 3845718.0, '05-08': 3938064.0, '05-09': 4024009.0, '05-10': 4101699.0, '05-11': 4177504.0, '05-12': 4261955.0, '05-13': 4347018.0, '05-14': 4442163.0, '05-15': 4542347.0, '05-16': 4634068.0, '05-17': 4713620.0, '05-18': 4801943.0, '05-19': 4897492.0, '05-20': 4996472.0, '05-21': 5102424.0, '05-22': 5210817.0, '05-23': 5310362.0, '05-24': 5407613.0, '05-25': 5495061.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,confirmed,s=100)
plt.show()

# %%
new_time_confirmed={}
for key in time_confirmed.keys():
    if key!='05-01':
        new_time_confirmed[key]=time_confirmed[key]-time_confirmed['05-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_confirmed)
time1=new_time_confirmed.keys()
confirmed1=new_time_confirmed.values()
plt.figure(dpi=800)
plt.title('new confirmed')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of confirmed",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,confirmed1,s=100)
plt.show()
# Out:
# {'05-02': 83566.0, '05-03': 79386.0, '05-04': 76326.0, '05-05': 79636.0, '05-06': 92650.0, '05-07': 90377.0, '05-08': 92346.0, '05-09': 85945.0, '05-10': 77690.0, '05-11': 75805.0, '05-12': 84451.0, '05-13': 85063.0, '05-14': 95145.0, '05-15': 100184.0, '05-16': 91721.0, '05-17': 79552.0, '05-18': 88323.0, '05-19': 95549.0, '05-20': 98980.0, '05-21': 105952.0, '05-22': 108393.0, '05-23': 99545.0, '05-24': 97251.0, '05-25': 87448.0}

# %%
confirm=[]
for i in confirmed:
    confirm.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time,confirm,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
confirmed2=[]
for i in confirmed1:
    confirmed2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New confirmed',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of confirmed',fontsize=16)
plt.plot(time2,confirmed2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, confirm, label='confirmed')
plt.title('cumulative confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, confirmed2, label='confirmed')
plt.title('new confirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of confirmed',fontsize = 24)
plt.show()
