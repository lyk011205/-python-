# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
area_death={}
areas_death={}
area_comfirmed={}
areas_comfirmed={}
area_recovered={}
areas_recovered={}
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            area_death[row[3]]=0
            area_comfirmed[row[3]]=0
            area_recovered[row[3]]=0
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[7]!=''and row[8]!='Deaths' and row[3]!=''and row[8]!='':
                area_death[row[3]]=area_death[row[3]]+int(row[8])
                area_comfirmed[row[3]]=area_comfirmed[row[3]]+int(row[7])
                area_recovered[row[3]]=area_recovered[row[3]]+int(row[9])
print(area_death)
#print( sorted(area_death.items(), key=lambda x: x[1], reverse=True)[0][0])
for i in range(0,5):
    areas_death[sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_death.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_comfirmed[sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_comfirmed.items(), key=lambda x: x[1], reverse=True)[i][1])
    areas_recovered[sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][0]]=int(sorted(area_recovered.items(), key=lambda x: x[1], reverse=True)[i][1])
print(areas_death)
print(areas_comfirmed)
print(areas_recovered)
areas1=areas_death.keys()
death=areas_death.values()
areas2=areas_comfirmed.keys()
comfirmed = areas_comfirmed.values()
areas3=areas_recovered.keys()
recovered = areas_recovered.values()
# Out:
# {'US': 2081910, 'Canada': 131861, 'United Kingdom': 822883, 'China': 115935, 'Netherlands': 137650, 'Australia': 2453, 'Denmark': 13230, 'France': 672969, 'Afghanistan': 3560, 'Albania': 777, 'Algeria': 13094, 'Andorra': 1212, 'Angola': 61, 'Antigua and Barbuda': 75, 'Argentina': 8483, 'Armenia': 1332, 'Austria': 15514, 'Azerbaijan': 883, 'Bahamas': 275, 'Bahrain': 254, 'Bangladesh': 7279, 'Barbados': 175, 'Belarus': 3657, 'Belgium': 217559, 'Belize': 50, 'Benin': 55, 'Bhutan': 0, 'Bolivia': 3707, 'Bosnia and Herzegovina': 2836, 'Botswana': 25, 'Brazil': 346140, 'Brunei': 25, 'Bulgaria': 2473, 'Burkina Faso': 1238, 'Burma': 150, 'Burundi': 25, 'Cabo Verde': 59, 'Cambodia': 0, 'Cameroon': 3038, 'Central African Republic': 3, 'Chad': 959, 'Chile': 10301, 'Colombia': 12893, 'Comoros': 20, 'Congo (Brazzaville)': 315, 'Congo (Kinshasa)': 1213, 'Costa Rica': 200, "Cote d'Ivoire": 581, 'Croatia': 2264, 'Cuba': 1895, 'Cyprus': 404, 'Czechia': 7107, 'Diamond Princess': 325, 'Djibouti': 126, 'Dominica': 0, 'Dominican Republic': 10067, 'Ecuador': 57046, 'Egypt': 14338, 'El Salvador': 561, 'Equatorial Guinea': 147, 'Eritrea': 0, 'Estonia': 1504, 'Eswatini': 45, 'Ethiopia': 113, 'Fiji': 0, 'Finland': 6896, 'Gabon': 229, 'Gambia': 25, 'Georgia': 267, 'Germany': 192148, 'Ghana': 613, 'Greece': 3912, 'Grenada': 0, 'Guatemala': 807, 'Guinea': 342, 'Guinea-Bissau': 87, 'Guyana': 247, 'Haiti': 436, 'Holy See': 0, 'Honduras': 3135, 'Hungary': 10538, 'Iceland': 250, 'India': 64992, 'Indonesia': 26666, 'Iran': 169758, 'Iraq': 2977, 'Ireland': 36847, 'Israel': 6465, 'Italy': 774432, 'Jamaica': 223, 'Japan': 16625, 'Jordan': 224, 'Kazakhstan': 798, 'Kenya': 960, 'Korea, South': 6487, 'Kosovo': 689, 'Kuwait': 2145, 'Kyrgyzstan': 311, 'Laos': 0, 'Latvia': 472, 'Lebanon': 642, 'Liberia': 526, 'Libya': 75, 'Liechtenstein': 25, 'Lithuania': 1337, 'Luxembourg': 2568, 'MS Zaandam': 50, 'Madagascar': 16, 'Malawi': 77, 'Malaysia': 2753, 'Maldives': 78, 'Mali': 1106, 'Malta': 134, 'Mauritania': 71, 'Mauritius': 250, 'Mexico': 110586, 'Moldova': 4652, 'Monaco': 100, 'Mongolia': 0, 'Montenegro': 215, 'Morocco': 4701, 'Mozambique': 1, 'Namibia': 0, 'Nepal': 25, 'New Zealand': 521, 'Nicaragua': 226, 'Niger': 1214, 'Nigeria': 3892, 'North Macedonia': 2418, 'Norway': 5634, 'Oman': 527, 'Pakistan': 19174, 'Panama': 6326, 'Papua New Guinea': 0, 'Paraguay': 263, 'Peru': 56569, 'Philippines': 18814, 'Poland': 21193, 'Portugal': 29311, 'Qatar': 375, 'Romania': 25175, 'Russia': 56774, 'Rwanda': 0, 'Saint Kitts and Nevis': 0, 'Saint Lucia': 0, 'Saint Vincent and the Grenadines': 0, 'San Marino': 1028, 'Sao Tome and Principe': 141, 'Saudi Arabia': 6914, 'Senegal': 535, 'Serbia': 5462, 'Seychelles': 0, 'Sierra Leone': 598, 'Singapore': 517, 'Slovakia': 664, 'Slovenia': 2543, 'Somalia': 1250, 'South Africa': 6189, 'South Sudan': 58, 'Spain': 672154, 'Sri Lanka': 219, 'Sudan': 2183, 'Suriname': 25, 'Sweden': 84869, 'Switzerland': 46244, 'Syria': 79, 'Taiwan*': 165, 'Tajikistan': 633, 'Tanzania': 490, 'Thailand': 1388, 'Timor-Leste': 0, 'Togo': 268, 'Trinidad and Tobago': 200, 'Tunisia': 1126, 'Turkey': 97530, 'Uganda': 0, 'Ukraine': 11127, 'United Arab Emirates': 4879, 'Uruguay': 474, 'Uzbekistan': 278, 'Venezuela': 250, 'Vietnam': 0, 'West Bank and Gaza': 53, 'Western Sahara': 0, 'Yemen': 409, 'Zambia': 146, 'Zimbabwe': 100, 'Lesotho': 0}
# {'US': 2081910, 'United Kingdom': 822883, 'Italy': 774432, 'France': 672969, 'Spain': 672154}
# {'US': 34805140, 'Russia': 5954979, 'United Kingdom': 5677222, 'Spain': 5673177, 'Italy': 5523528}
# {'US': 6275981, 'Germany': 3681360, 'Spain': 3449807, 'Italy': 2797923, 'Turkey': 2396939}

# %% [markdown]
# 列举五月前五的death地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas1, death, label='death')
plt.title('death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of death',fontsize = 24)
plt.show()

# %% [markdown]
# 列举五月前五的comfirmed地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas2, comfirmed, label='comfirmed')
plt.title('comfirmed',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of comfirmed',fontsize = 24)
plt.show()

# %% [markdown]
# 列举五月前五的recovered地区或国家

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(areas3, recovered, label='recovered')
plt.title('recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('top five num of recovered',fontsize = 24)
plt.show()
