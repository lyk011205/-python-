# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time = []
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['05-'+str(num).zfill(2)]=0
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[9]!=''and row[9]!='Recovered':
                time_recovered['05-'+str(num).zfill(2)]=float(row[9])+time_recovered['05-'+str(num).zfill(2)]
print(time_recovered)
times,recovered=time_recovered.keys(),time_recovered.values()
for i in times:
    time.append(i)
# Out:
# {'05-01': 1053327.0, '05-02': 1093112.0, '05-03': 1125236.0, '05-04': 1162724.0, '05-05': 1198832.0, '05-06': 1245413.0, '05-07': 1284741.0, '05-08': 1322050.0, '05-09': 1375624.0, '05-10': 1408980.0, '05-11': 1456209.0, '05-12': 1493414.0, '05-13': 1548547.0, '05-14': 1587893.0, '05-15': 1637067.0, '05-16': 1693197.0, '05-17': 1733963.0, '05-18': 1786875.0, '05-19': 1838995.0, '05-20': 1897466.0, '05-21': 1948739.0, '05-22': 2056643.0, '05-23': 2112185.0, '05-24': 2168563.0, '05-25': 2231738.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,recovered,s=100)
plt.show()

# %%
new_time_recovered={}
for key in time_recovered.keys():
    if key!='05-01':
        new_time_recovered[key]=time_recovered[key]-time_recovered['05-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_recovered)
time1=new_time_recovered.keys()
recover1=new_time_recovered.values()
plt.figure(dpi=800)
plt.title('new recovered')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,recover1,s=100)
plt.show()
# Out:
# {'05-02': 39785.0, '05-03': 32124.0, '05-04': 37488.0, '05-05': 36108.0, '05-06': 46581.0, '05-07': 39328.0, '05-08': 37309.0, '05-09': 53574.0, '05-10': 33356.0, '05-11': 47229.0, '05-12': 37205.0, '05-13': 55133.0, '05-14': 39346.0, '05-15': 49174.0, '05-16': 56130.0, '05-17': 40766.0, '05-18': 52912.0, '05-19': 52120.0, '05-20': 58471.0, '05-21': 51273.0, '05-22': 107904.0, '05-23': 55542.0, '05-24': 56378.0, '05-25': 63175.0}

# %%
recover=[]
for i in recovered:
    recover.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative Recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time,recover,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
recover2=[]
for i in recover1:
    recover2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered',fontsize=16)
plt.plot(time2,recover2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, recover, label='recovered')
plt.title('cumulative recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, recover2, label='recovered')
plt.title('new recovered',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered',fontsize = 24)
plt.show()
