# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_recovered={}
time_death={}
r_d=[]
time = []
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_recovered['05-'+str(num).zfill(2)]=0
            time_death['05-'+str(num).zfill(2)]=0
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[9]!=''and row[9]!='Recovered'and row[8]!='Deaths'and row[8]!='':
                time_recovered['05-'+str(num).zfill(2)]=float(row[9])+time_recovered['05-'+str(num).zfill(2)]
                time_death['05-'+str(num).zfill(2)]=float(row[8])+time_death['05-'+str(num).zfill(2)]
times,recovered=time_recovered.keys(),time_recovered.values()
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
death=[]
for i in deaths:
    death.append(i)
recover=[]
for i in recovered:
    recover.append(i)
lens = len(time)
for i in range(lens):
    r_d.append(recover[i]-death[i])
print(r_d)
print(time)
# Out:
# [814677.0, 849304.0, 877766.0, 911187.0, 941593.0, 981582.0, 1015174.0, 1047152.0, 1096313.0, 1126271.0, 1169879.0, 1201450.0, 1251350.0, 1285475.0, 1329401.0, 1381416.0, 1418778.0, 1468394.0, 1515710.0, 1569351.0, 1615815.0, 1718483.0, 1770088.0, 1823504.0, 1885506.0]
# ['05-01', '05-02', '05-03', '05-04', '05-05', '05-06', '05-07', '05-08', '05-09', '05-10', '05-11', '05-12', '05-13', '05-14', '05-15', '05-16', '05-17', '05-18', '05-19', '05-20', '05-21', '05-22', '05-23', '05-24', '05-25']

# %%
plt.figure(dpi=800)
plt.title('cumulative Recovered - Death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of recovered - death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,r_d,s=100)

# %%
new={}
for key in time_recovered.keys():
    if key!='05-01':
        new[key]=time_recovered[key]-time_recovered['05-'+str(int(key[3:5])-1).zfill(2)]-time_death[key]+time_death['05-'+str(int(key[3:5])-1).zfill(2)]
print(new)
time1=new.keys()
value1=new.values()
plt.figure(dpi=800)
plt.title('new recovered-death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of  recovered-death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,value1,s=100)
plt.show()
# Out:
# {'05-02': 34627.0, '05-03': 28462.0, '05-04': 33421.0, '05-05': 30406.0, '05-06': 39989.0, '05-07': 33592.0, '05-08': 31978.0, '05-09': 49161.0, '05-10': 29958.0, '05-11': 43608.0, '05-12': 31571.0, '05-13': 49900.0, '05-14': 34125.0, '05-15': 43926.0, '05-16': 52015.0, '05-17': 37362.0, '05-18': 49616.0, '05-19': 47316.0, '05-20': 53641.0, '05-21': 46464.0, '05-22': 102668.0, '05-23': 51605.0, '05-24': 53416.0, '05-25': 62002.0}

# %%
fig = plt.figure(dpi=128,figsize=(10,6))
plt.title('cumulative Recovered - Death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time,r_d,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
value2=[]
for i in value1:
    value2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New recovered - death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of recovered - death',fontsize=16)
plt.plot(time2,value2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(18,10))
plt.bar(time, r_d, label='Recovered - Death')
plt.title('cumulative Recovered - Death',fontsize=24)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of recovered - death',fontsize = 16)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, value2, label='Recovered - Death')
plt.title('new Recovered - Death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of Recovered - Death',fontsize = 24)
plt.show()
