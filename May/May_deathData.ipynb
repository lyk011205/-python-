# %%
import csv
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
time_death={}
time = []
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv'
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)
        for row in reader:
            time_death['05-'+str(num).zfill(2)]=0
for num in range(1,26):
    filename='C:\\Users\\86188\\Desktop\\COVID-19-master\\csse_covid_19_data\\csse_covid_19_daily_reports\\05-'+str(num).zfill(2)+'-2020.csv' 
    with open(filename) as f:
        reader1 = csv.reader(f)
        for row in reader1:
            if row[8]!=''and row[8]!='Deaths':
                time_death['05-'+str(num).zfill(2)]=float(row[8])+time_death['05-'+str(num).zfill(2)]
print(time_death)
times,deaths=time_death.keys(),time_death.values()
for i in times:
    time.append(i)
# Out:
# {'05-01': 238650.0, '05-02': 243808.0, '05-03': 247470.0, '05-04': 251537.0, '05-05': 257239.0, '05-06': 263831.0, '05-07': 269567.0, '05-08': 274898.0, '05-09': 279311.0, '05-10': 282709.0, '05-11': 286330.0, '05-12': 291964.0, '05-13': 297197.0, '05-14': 302418.0, '05-15': 307666.0, '05-16': 311781.0, '05-17': 315185.0, '05-18': 318481.0, '05-19': 323285.0, '05-20': 328115.0, '05-21': 332924.0, '05-22': 338160.0, '05-23': 342097.0, '05-24': 345059.0, '05-25': 346232.0}

# %%
plt.figure(dpi=800)
plt.title('cumulative death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time,deaths,s=100)
plt.show()

# %%
new_time_death={}
for key in time_death.keys():
    if key!='05-01':
        new_time_death[key]=time_death[key]-time_death['05-'+str(int(key[3:5])-1).zfill(2)]
print(new_time_death)
time1=new_time_death.keys()
death1=new_time_death.values()
plt.figure(dpi=800)
plt.title('new death')
plt.xlabel("date",fontsize=14)
plt.ylabel("num of death",fontsize=14)
plt.tick_params(axis='both',which='major',labelsize=3)
plt.scatter(time1,death1,s=100)
plt.show()
# Out:
# {'05-02': 5158.0, '05-03': 3662.0, '05-04': 4067.0, '05-05': 5702.0, '05-06': 6592.0, '05-07': 5736.0, '05-08': 5331.0, '05-09': 4413.0, '05-10': 3398.0, '05-11': 3621.0, '05-12': 5634.0, '05-13': 5233.0, '05-14': 5221.0, '05-15': 5248.0, '05-16': 4115.0, '05-17': 3404.0, '05-18': 3296.0, '05-19': 4804.0, '05-20': 4830.0, '05-21': 4809.0, '05-22': 5236.0, '05-23': 3937.0, '05-24': 2962.0, '05-25': 1173.0}

# %%
death=[]
for i in deaths:
    death.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('cumulative death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time,death,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
death2=[]
for i in death1:
    death2.append(i)
time2=[]
for i in time1:
    time2.append(i)
fig = plt.figure(dpi=128,figsize=(10,10))
plt.title('New death',fontsize=24)
plt.xlabel('date',fontsize=16)
plt.ylabel('num of death',fontsize=16)
plt.plot(time2,death2,c='red')
plt.tick_params(axis='both',which='major',labelsize=5)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time, death, label='death')
plt.title('cumulative death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()

# %%
plt.figure(dpi=128,figsize=(20,10))
plt.bar(time2, death1, label='death')
plt.title('new death',fontsize=25)
plt.legend()
plt.xlabel('data',fontsize = 16)
plt.ylabel('num of death',fontsize = 24)
plt.show()
